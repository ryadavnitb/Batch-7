# %%
import pandas

# %%
import numpy

# %%
import matplotlib

# %%
import seaborn

# %%
from google.colab import files
uploaded = files.upload()


import io
import pandas as pd


df = pd.read_csv(io.BytesIO(uploaded['airlines_flights_data.csv']))


df.head()
# Out:
#      <input type="file" id="files-c5370601-fa27-4c78-af39-8f17eeddf70e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c5370601-fa27-4c78-af39-8f17eeddf70e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive ;drive.mount('/content/drive')



import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/airlines_flights_data.csv')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/airlines_flights_data.csv')

# %%
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          index   airline   flight source_city departure_time stops  \
# 0            0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1            1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2            2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3            3   Vistara   UK-995       Delhi        Morning  zero
# 4            4   Vistara   UK-963       Delhi        Morning  zero
# ...        ...       ...      ...         ...            ...   ...
# 300148  300148   Vistara   UK-822     Chennai        Morning   one
# 300149  300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150  300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151  300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152  300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
df.head()


df.shape


df.columns


df.info()

df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB
#                index       duration      days_left          price
# ...

# %%
df.mean(numeric_only=True)


df.std(numeric_only=True)


df['price'].mean()
df['price'].std()
# Out:
# 22697.767366075885

# %%
df.isnull().sum()


df.isna().sum()


df[df['price'].isna()].head(4)
# Out:
# Empty DataFrame
# Columns: [index, airline, flight, source_city, departure_time, stops, arrival_time, destination_city, class, duration, days_left, price]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['level_0']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'level_0'}, axis=1)
#               .sort_values('level_0', ascending=True))
#   xs = counted['level_0']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_0.sort_values('level_0', ascending=True)
# ...

# %%
df.describe()


df['price'].isnull().sum()


df[df['price'].isna()].head(4)

df.groupby('airline')['price'].median()

#histogram for price
import matplotlib.pyplot as plt

plt.hist(df['price'].dropna(), bins=30, edgecolor='black')
plt.title('Distribution of Flight Prices')
plt.xlabel('Flight Price (₹)')
plt.ylabel('Frequency')
plt.show()

# %%
df.groupby('airline')['price'].median()

df.groupby('source_city')['duration'].mean()

df.groupby('class')['price'].describe()
# Out:
#              count          mean           std      min      25%      50%  \
# class
# Business   93487.0  52540.081124  12969.314606  12000.0  45185.0  53164.0
# Economy   206666.0   6572.342383   3743.519517   1105.0   4173.0   5772.0
#
#               75%       max
# class
# Business  60396.0  123071.0
# Economy    7746.0   42349.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.heatmap(df[['duration', 'days_left', 'price']].corr(), annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()



plt.figure(figsize=(10,5))
sns.boxplot(x='airline', y='price', data=df)
plt.title('Flight Price Distribution by Airline')
plt.xticks(rotation=45)
plt.show()



plt.figure(figsize=(6,4))
sns.boxplot(x='class', y='price', data=df)
plt.title('Price Comparison by Ticket Class')
plt.show()



avg_price_by_days = df.groupby('days_left')['price'].mean()

plt.figure(figsize=(8,4))
avg_price_by_days.plot(kind='line', marker='o')
plt.title('Average Flight Price vs. Days Left for Departure')
plt.xlabel('Days Left')
plt.ylabel('Average Price (₹)')
plt.grid(True)
plt.show()

# %%
def optimize_memory(df):
    for col in df.columns:
        col_type = df[col].dtype

        # Convert object type columns with repeat values → category
        if col_type == 'object':
            if df[col].nunique() < df.shape[0] * 0.5:
                df[col] = df[col].astype('category')

        # Downcast integers
        elif col_type in ['int64', 'int32']:
            df[col] = pd.to_numeric(df[col], downcast='integer')

        # Downcast floats
        elif col_type in ['float64', 'float32']:
            df[col] = pd.to_numeric(df[col], downcast='float')

    return df

df = optimize_memory(df)

print("✅ Optimized Memory Usage (MB): ", df.memory_usage(deep=True).sum() / 1024**2)
# Out:
# ✅ Optimized Memory Usage (MB):  6.414773941040039

# %%
sample_fraction = 0.10  # change to 0.20 for 20%, etc.

df_sample = df.sample(frac=sample_fraction, random_state=42)

print(f"📌 Sample Created: {df_sample.shape[0]} rows selected out of {df.shape[0]}")
# Out:
# 📌 Sample Created: 30015 rows selected out of 300153

# %%
print("Original Shape:", df.shape)
print("Sampled Shape:", df_sample.shape)

print("\nColumn Comparison:")
print(df.describe(include='all'))
print(df_sample.describe(include='all'))
# Out:
# Original Shape: (300153, 12)
# Sampled Shape: (30015, 12)
#
# Column Comparison:
#                 index  airline  flight source_city departure_time   stops  \
# count   300153.000000   300153  300153      300153         300153  300153
# unique            NaN        6    1561           6              6       3
# top               NaN  Vistara  UK-706       Delhi        Morning     one
# freq              NaN   127859    3235       61343          71146  250863
# mean    150076.000000      NaN     NaN         NaN            NaN     NaN
# std      86646.852011      NaN     NaN         NaN            NaN     NaN
# min          0.000000      NaN     NaN         NaN            NaN     NaN
# 25%      75038.000000      NaN     NaN         NaN            NaN     NaN
# 50%     150076.000000      NaN     NaN         NaN            NaN     NaN
# 75%     225114.000000      NaN     NaN         NaN            NaN     NaN
# max     300152.000000      NaN     NaN         NaN            NaN     NaN
#
# ...

# %%
categorical_column = df.select_dtypes(include=['category']).columns.tolist()

if categorical_column:
    print("\n Checking sampling balance for categorical columns:")
    for col in categorical_column:
        print(f"\nCategory distribution in {col}:")
        print("Original:")
        print(df[col].value_counts(normalize=True) * 100)

        print("\nSample:")
        print(df_sample[col].value_counts(normalize=True) * 100)
# Out:
# 🔍 Checking sampling balance for categorical columns:
#
# Category distribution in airline:
# Original:
# airline
# Vistara      42.597942
# Air_India    26.950255
# Indigo       14.366007
# GO_FIRST      7.720396
# AirAsia       5.363265
# SpiceJet      3.002136
# Name: proportion, dtype: float64
#
# Sample:
# airline
# Vistara      42.408796
# Air_India    27.066467
# Indigo       14.462769
# GO_FIRST      7.746127
# AirAsia       5.437281
# SpiceJet      2.878561
# Name: proportion, dtype: float64
#
# Category distribution in flight:
# Original:
# flight
# UK-706     1.077784
# UK-772     0.913201
# UK-720     0.882883
# UK-836     0.846901
# UK-822     0.822247
#              ...
# SG-1058    0.000333
# G8-405     0.000333
# 6E-3211    0.000333
# 6E-2939    0.000333
# 6E-2914    0.000333
# Name: proportion, Length: 1561, dtype: float64
#
# Sample:
# flight
# UK-706       1.062802
# UK-874       0.876229
# UK-828       0.859570
# UK-772       0.836249
# UK-720       0.816259
# ...

# %%
del df
import gc
gc.collect()

print("Original dataset removed from memory to save RAM.")
# Out:
# Original dataset removed from memory to save RAM.

# %%
df_sample.reset_index(drop=True, inplace=True)
df_sample.head()
# Out:
#     index    airline  flight source_city departure_time stops   arrival_time  \
# 0   27131  Air_India  AI-506       Delhi        Morning   one  Early_Morning
# 1  266857    Vistara  UK-706     Kolkata        Morning   one          Night
# 2  141228    Vistara  UK-772     Kolkata        Morning   one          Night
# 3  288329    Vistara  UK-824     Chennai          Night   one        Morning
# 4   97334  Air_India  AI-501   Bangalore      Afternoon   one          Night
#
#   destination_city     class  duration  days_left  price
# 0          Kolkata   Economy     19.75         40   7366
# 1           Mumbai  Business      9.83         42  64831
# 2        Bangalore   Economy     10.50         41   6195
# 3            Delhi  Business     14.50         14  60160
# 4           Mumbai   Economy      8.25         20   6578

# %%
[col for col in df_sample.columns if 'delay' in col.lower() or 'cancel' in col.lower()]
# Out:
# []

# %%
delay_cols = [col for col in df_sample.columns if 'delay' in col.lower()]

for col in delay_cols:
    df_sample[col] = df_sample[col].fillna(0)

# %%
cancel_cols = [col for col in df_sample.columns if 'cancel' in col.lower()]

for col in cancel_cols:
    df_sample[col] = df_sample[col].fillna(0).astype(int)

# %%
if 'CancellationReason' in df_sample.columns:
    df_sample['CancellationReason'] = df_sample['CancellationReason'].fillna("No Reason")

# %%
df_sample[delay_cols + cancel_cols].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
# Check first 20 values
df['departure_time'].head(20)
# Out:
# 0           Evening
# 1     Early_Morning
# 2     Early_Morning
# 3           Morning
# 4           Morning
# 5           Morning
# 6           Morning
# 7         Afternoon
# 8     Early_Morning
# 9         Afternoon
# 10        Afternoon
# 11          Morning
# 12    Early_Morning
# 13          Morning
# 14        Afternoon
# 15          Morning
# 16    Early_Morning
# 17    Early_Morning
# 18          Evening
# 19          Evening
# Name: departure_time, dtype: object

# %%
time_mapping = {
    "Early Morning": 6,
    "Morning": 9,
    "Afternoon": 14,
    "Evening": 18,
    "Night": 21
}

df['Hour'] = df['departure_time'].map(time_mapping)

# %%
# Route feature
df['Route'] = df['source_city'] + " → " + df['destination_city']

# %%
df.columns
# Out:
# Index(['index', 'airline', 'flight', 'source_city', 'departure_time', 'stops',
#        'arrival_time', 'destination_city', 'class', 'duration', 'days_left',
#        'price', 'Hour', 'Route'],
#       dtype='object')

# %%
import pandas as pd
import datetime

# If not already loaded
# df = pd.read_csv('your_file.csv')

# Assume 'departure_time' is text like "2025-11-27 Evening"
# Extract date part if present (YYYY-MM-DD)
df['departure_date'] = df['departure_time'].str.extract(r'(\d{4}-\d{2}-\d{2})')

# Convert to datetime
df['departure_date'] = pd.to_datetime(df['departure_date'], errors='coerce')  # NaT if invalid

# Format datetime (optional)
df['departure_date'] = df['departure_date'].dt.strftime('%Y-%m-%d')  # Standard YYYY-MM-DD format

# Derived features from datetime
df['Month'] = pd.to_datetime(df['departure_date'], errors='coerce').dt.month
df['Day_of_Week'] = pd.to_datetime(df['departure_date'], errors='coerce').dt.day_name()

# Hour already mapped (from text like "Morning", "Evening")
# Route already created
# df['Hour'], df['Route']

df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price  Hour           Route  \
# 0           Mumbai  Economy      2.17          1   5953  18.0  Delhi → Mumbai
# 1           Mumbai  Economy      2.33          1   5953   NaN  Delhi → Mumbai
# 2           Mumbai  Economy      2.17          1   5956   NaN  Delhi → Mumbai
# 3           Mumbai  Economy      2.25          1   5955   9.0  Delhi → Mumbai
# 4           Mumbai  Economy      2.33          1   5955   9.0  Delhi → Mumbai
#
#   departure_date  Month Day_of_Week
# ...

# %%
import pandas as pd
import datetime


# ---------------------------
# 1. Format and clean datetime
# ---------------------------

# Extract date part from 'departure_time' if it contains actual dates
df['departure_date'] = df['departure_time'].str.extract(r'(\d{4}-\d{2}-\d{2})')
df['departure_date'] = pd.to_datetime(df['departure_date'], errors='coerce')  # Convert to datetime
df['departure_date'] = df['departure_date'].dt.strftime('%Y-%m-%d')  # Standard YYYY-MM-DD format

# ---------------------------
# 2. Derived features from datetime
# ---------------------------
df['Month'] = pd.to_datetime(df['departure_date'], errors='coerce').dt.month
df['Day_of_Week'] = pd.to_datetime(df['departure_date'], errors='coerce').dt.day_name()

# ---------------------------
# 3. Map departure_time text to Hour
# ---------------------------
time_mapping = {
    "Early Morning": 6,
    "Morning": 9,
    "Afternoon": 14,
    "Evening": 18,
    "Night": 21
}
df['Hour'] = df['departure_time'].map(time_mapping)

# ---------------------------
# 4. Create Route feature
# ---------------------------
df['Route'] = df['source_city'] + " → " + df['destination_city']

# ---------------------------
# 5. Check final DataFrame
# ---------------------------
print(df[['departure_time','departure_date','Month','Day_of_Week','Hour','Route']].head())
# Out:
#   departure_time departure_date  Month Day_of_Week  Hour           Route
# 0        Evening            NaN    NaN         NaN  18.0  Delhi → Mumbai
# 1  Early_Morning            NaN    NaN         NaN   NaN  Delhi → Mumbai
# 2  Early_Morning            NaN    NaN         NaN   NaN  Delhi → Mumbai
# 3        Morning            NaN    NaN         NaN   9.0  Delhi → Mumbai
# 4        Morning            NaN    NaN         NaN   9.0  Delhi → Mumbai

# %%
# Save the preprocessed DataFrame to a CSV in the Colab session
df.to_csv('airlines_flights_data_preprocessed.csv', index=False)

# Optional: save directly to Google Drive for permanent storage
from google.colab import drive
drive.mount('/content/drive')

# Replace with your desired path in Google Drive
df.to_csv('/content/drive/MyDrive/airlines_flights_data_preprocessed.csv', index=False)

print("Preprocessed dataset saved successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Preprocessed dataset saved successfully!

# %%
# Univariate Analysis

# %%
# Install Excel reader
# !pip install openpyxl

# Imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# Upload Excel file
from google.colab import files
uploaded = files.upload()

df = pd.read_csv(list(uploaded.keys())[0])
df.head()
# Out:
# ...
#      <input type="file" id="files-cbccfcbd-5d64-47fb-9a20-941ca854c8f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbccfcbd-5d64-47fb-9a20-941ca854c8f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.figure(figsize=(12,6))
df['airline'].value_counts().plot(kind='bar')
plt.title("Top Airlines by Number of Flights")
plt.xlabel("Airline")
plt.ylabel("Flight Count")
plt.xticks(rotation=45)
plt.show()

# %%
df['Route'] = df['source_city'] + " → " + df['destination_city']

plt.figure(figsize=(14,6))
df['Route'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Busiest Routes")
plt.xlabel("Route")
plt.ylabel("Flight Count")
plt.xticks(rotation=45)
plt.show()

# %%
df['days_left_bucket'] = pd.cut(df['days_left'],
                                bins=[0, 7, 15, 30, 60, 90],
                                labels=['0–7', '8–15', '16–30', '31–60', '61–90'])

plt.figure(figsize=(12,5))
df['days_left_bucket'].value_counts().sort_index().plot(kind='bar')
plt.title("Flight Count by Days Before Departure")
plt.xlabel("Days Left Group")
plt.ylabel("Number of Flights")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df, x='departure_time')
plt.title("Flight Distribution by Departure Time")
plt.xlabel("Departure Time Slot")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))
df['source_city'].value_counts().plot(kind='bar')
plt.title("Flights by Source City")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12,6))
df['destination_city'].value_counts().plot(kind='bar')
plt.title("Flights by Destination City")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['duration'], kde=True)
plt.title("Distribution of Flight Duration")
plt.xlabel("Duration (hours)")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=df, x='airline', y='price')
plt.xticks(rotation=45)
plt.title("Flight Price Distribution by Airline")
plt.show()

# %%
avg_price = df.groupby('days_left')['price'].mean()

plt.figure(figsize=(12,5))
plt.plot(avg_price.index, avg_price.values, marker='o')
plt.title("Average Price vs Days Left")
plt.xlabel("Days Left")
plt.ylabel("Average Price")
plt.grid(True)
plt.show()

# %% [markdown]
# **Week 4: Delay Analysis – Airline and Weather**

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("airlines_flights_data.csv")

# Show first few rows to confirm df is loaded
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df.groupby('airline')['duration'].mean().round(2)
# Out:
# airline
# AirAsia       8.94
# Air_India    15.50
# GO_FIRST      8.76
# Indigo        5.80
# SpiceJet     12.58
# Vistara      13.33
# Name: duration, dtype: float64

# %%
df.groupby('airline')['price'].mean().round(2)
# Out:
# airline
# AirAsia       4091.07
# Air_India    23507.02
# GO_FIRST      5652.01
# Indigo        5324.22
# SpiceJet      6179.28
# Vistara      30396.54
# Name: price, dtype: float64

# %%
df.groupby('airline')['stops'].value_counts()
# Out:
# airline    stops
# AirAsia    one             11418
#            zero             2434
#            two_or_more      2246
# Air_India  one             71004
#            zero             6409
#            two_or_more      3479
# GO_FIRST   one             19545
#            zero             3223
#            two_or_more       405
# Indigo     one             31166
#            zero            11216
#            two_or_more       738
# SpiceJet   one              6549
#            zero             2462
# Vistara    one            111181
#            zero            10260
#            two_or_more      6418
# Name: count, dtype: int64

# %%
df.groupby('airline')['flight'].count()
# Out:
# airline
# AirAsia       16098
# Air_India     80892
# GO_FIRST      23173
# Indigo        43120
# SpiceJet       9011
# Vistara      127859
# Name: flight, dtype: int64

# %%
time_order = ["Early_Morning", "Morning", "Afternoon", "Evening", "Night"]

df["departure_time"] = pd.Categorical(df["departure_time"],
                                      categories=time_order,
                                      ordered=True)

# %%
plt.figure(figsize=(10,5))
df.groupby("source_city")["duration"].mean().plot(kind="bar")

plt.title("Average Duration by Source City")
plt.xlabel("Source City")
plt.ylabel("Average Duration (Hours)")
plt.xticks(rotation=45)
plt.show()

# %%
pivot = df.pivot_table(
    values="duration",
    index="departure_time",
    columns="source_city",
    aggfunc="mean"
)
# Out:
# /tmp/ipython-input-4220984742.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot = df.pivot_table(

# %%
plt.figure(figsize=(10,6))
sns.heatmap(pivot, annot=True, fmt=".2f", cmap="Blues")
plt.title("Average Delay (Duration) by Time of Day and Airport")
plt.xlabel("Source Airport")
plt.ylabel("Time of Day")
plt.show()

# %%
print(df['departure_time'].head(20))
print(df['departure_time'].unique()[:50])
# Out:
# 0           Evening
# 1     Early_Morning
# 2     Early_Morning
# 3           Morning
# 4           Morning
# 5           Morning
# 6           Morning
# 7         Afternoon
# 8     Early_Morning
# 9         Afternoon
# 10        Afternoon
# 11          Morning
# 12    Early_Morning
# 13          Morning
# 14        Afternoon
# 15          Morning
# 16    Early_Morning
# 17    Early_Morning
# 18          Evening
# 19          Evening
# Name: departure_time, dtype: object
# ['Evening' 'Early_Morning' 'Morning' 'Afternoon' 'Night' 'Late_Night']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Mapping categories to approximate hours
time_map = {
    "Early_Morning": 5,
    "Morning": 9,
    "Afternoon": 14,
    "Evening": 18,
    "Night": 22,
    "Late_Night": 2
}

# Convert category → hour
df["dep_hour"] = df["departure_time"].map(time_map)

print("Mapped dep_hour values:", df["dep_hour"].notna().sum())

# Drop rows without mapping
df_clean = df.dropna(subset=["dep_hour", "duration", "source_city"])

# Aggregate for plotting
avg_df = df_clean.groupby(["source_city", "dep_hour"])["duration"].mean().reset_index()

print("Rows in aggregated df:", len(avg_df))
print(avg_df.head())

# Plot
if not avg_df.empty:
    g = sns.FacetGrid(avg_df, col="source_city", col_wrap=3, height=4)
    g.map_dataframe(sns.lineplot, x="dep_hour", y="duration", marker="o")
    g.set_axis_labels("Hour of Day", "Average Duration (hours)")
    g.set_titles("{col_name}")
    plt.show()
else:
    print("No data to plot. Check mapping or data.")
# Out:
# Mapped dep_hour values: 300153
# Rows in aggregated df: 36
#   source_city  dep_hour   duration
# 0   Bangalore         2  10.075667
# 1   Bangalore         5  11.533463
# 2   Bangalore         9  10.594286
# 3   Bangalore        14  10.521966
# 4   Bangalore        18  14.169044

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Map labels → hour ranges
time_bin_map = {
    "Early_Morning": (4, 8),   # 4 AM – 7:59 AM
    "Morning": (8, 12),        # 8 AM – 11:59 AM
    "Afternoon": (12, 17),     # 12 PM – 4:59 PM
    "Evening": (17, 21),       # 5 PM – 8:59 PM
    "Night": (21, 24),         # 9 PM – 11:59 PM
    "Late_Night": (0, 4)       # 12 AM – 3:59 AM
}

# Create a new category column for plotting
df["time_range"] = df["departure_time"].map(lambda x: f"{time_bin_map[x][0]}–{time_bin_map[x][1]}")

print(df["time_range"].head())

# Clean data
df_clean = df.dropna(subset=["time_range", "duration", "source_city"])

# Aggregate
avg_df = df_clean.groupby(["source_city", "time_range"])["duration"].mean().reset_index()

print(avg_df.head())
# Out:
# 0    17–21
# 1      4–8
# 2      4–8
# 3     8–12
# 4     8–12
# Name: time_range, dtype: object
#   source_city time_range   duration
# 0   Bangalore        0–4  10.075667
# 1   Bangalore      12–17  10.521966
# 2   Bangalore      17–21  14.169044
# 3   Bangalore      21–24  12.454733
# 4   Bangalore        4–8  11.533463

# %%
if not avg_df.empty:
    plt.figure(figsize=(14, 6))
    sns.barplot(
        data=avg_df,
        x="time_range",
        y="duration",
        hue="source_city"
    )
    plt.title("Average Flight Duration by Time of Day and Airport")
    plt.xlabel("Time of Day (Hour Range)")
    plt.ylabel("Avg Duration (Hours)")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("No data to plot.")

# %%
time_order = ["Late_Night", "Early_Morning", "Morning", "Afternoon", "Evening", "Night"]

df["departure_time"] = pd.Categorical(df["departure_time"], categories=time_order, ordered=True)

# %%
avg_df = df.groupby(["source_city", "departure_time"])["duration"].mean().reset_index()
print(avg_df.head())
# Out:
#   source_city departure_time   duration
# 0   Bangalore     Late_Night  10.075667
# 1   Bangalore  Early_Morning  11.533463
# 2   Bangalore        Morning  10.594286
# 3   Bangalore      Afternoon  10.521966
# 4   Bangalore        Evening  14.169044
# /tmp/ipython-input-189496287.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_df = df.groupby(["source_city", "departure_time"])["duration"].mean().reset_index()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
sns.lineplot(
    data=avg_df,
    x="departure_time",
    y="duration",
    hue="source_city",
    marker="o"
)

plt.title("Average Flight Duration by Time of Day and Airport")
plt.xlabel("Time of Day")
plt.ylabel("Average Duration (hours)")
plt.xticks(rotation=45)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
time_order = ["Late_Night", "Early_Morning", "Morning", "Afternoon", "Evening", "Night"]
df["departure_time"] = pd.Categorical(df["departure_time"], categories=time_order, ordered=True)

# %%
pivot_df = df.pivot_table(
    index="source_city",
    columns="departure_time",
    values="duration",
    aggfunc="mean"
)

print(pivot_df)
# Out:
# departure_time  Late_Night  Early_Morning    Morning  Afternoon    Evening  \
# source_city
# Bangalore        10.075667      11.533463  10.594286  10.521966  14.169044
# Chennai           7.221667      13.067938  11.943984  11.650868  12.115787
# Delhi             5.995322      10.616359  11.179610  10.249882  13.123983
# Hyderabad         2.170000      11.766315  11.757274  10.020728  12.626370
# Kolkata           5.162018      11.931694  11.940838  12.435191  14.663079
# Mumbai            6.062015      11.222406  10.629764  10.170104  14.081986
#
# departure_time      Night
# source_city
# Bangalore       12.454733
# Chennai         15.291432
# Delhi           12.196306
# Hyderabad       14.882078
# Kolkata         15.614641
# Mumbai          13.647768
# ...

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(
    pivot_df,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=.5
)

plt.title("Heatmap: Average Flight Duration by Airport & Time of Day")
plt.xlabel("Time of Day")
plt.ylabel("Source Airport / City")
plt.tight_layout()
plt.show()

# %%
sns.boxplot(data=df, x="airline", y="duration")
plt.xticks(rotation=45)
plt.title("Flight Duration by Airline")
plt.show()

# %%
sns.boxplot(data=df, x='time_range', y='duration')
plt.title("Duration by Time Range")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create time_range again
def categorize_time_range(x):
    if "Early" in x:
        return "Early_Morning"
    elif "Morning" in x:
        return "Morning"
    elif "Afternoon" in x:
        return "Afternoon"
    elif "Evening" in x:
        return "Evening"
    elif "Night" in x:
        return "Night"
    elif "Late" in x:
        return "Late_Night"
    else:
        return "Unknown"

df['time_range'] = df['departure_time'].apply(categorize_time_range)
print(df['time_range'].unique())
# Out:
# ['Evening' 'Early_Morning' 'Morning' 'Afternoon' 'Night']

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='days_left', y='duration', hue='time_range')
plt.title("Days Before Departure vs Duration")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt

# Calculate total delay (duration) by time of day
delay_by_time = df.groupby('time_range')['duration'].sum().sort_values()

plt.figure(figsize=(8,8))
plt.pie(delay_by_time, labels=delay_by_time.index, autopct='%1.1f%%', startangle=90)
plt.title("Delay Contribution by Time of Day")
plt.show()

# %% [markdown]
# Milestone 3: Route, Cancellation, and Seasonal Insights
#
# **Week 5: Route and Airport-Level Analysis**
#
# • Top 10 origin-destination pairs
#
# • Delay heatmaps by airport and route
#
# • Maps showing busiest airports and average delays

# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()

# Load the uploaded CSV
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)

df.head()
# Out:
#      <input type="file" id="files-50bfd8f4-1ec5-479a-a400-278eaa95f541" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50bfd8f4-1ec5-479a-a400-278eaa95f541">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Create a new column for route
df['route'] = df['source_city'] + " → " + df['destination_city']

# Count the frequency of each route
top_routes = df['route'].value_counts().head(10)

print(top_routes)
# Out:
# route
# Delhi → Mumbai        15289
# Mumbai → Delhi        14809
# Delhi → Bangalore     14012
# Bangalore → Delhi     13756
# Bangalore → Mumbai    12939
# Mumbai → Bangalore    12885
# Mumbai → Kolkata      12602
# Delhi → Kolkata       11934
# Kolkata → Mumbai      11467
# Delhi → Chennai       10780
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.barplot(x=top_routes.values, y=top_routes.index)
plt.title("Top 10 Most Popular Origin–Destination Route Pairs")
plt.xlabel("Number of Flights")
plt.ylabel("Route")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Use duration as delay proxy
delay_airport_time = df.pivot_table(
    index='source_city',
    columns='time_range',
    values='duration',
    aggfunc='mean'
)

plt.figure(figsize=(12,6))
sns.heatmap(delay_airport_time, annot=True, fmt=".2f", cmap='Reds')
plt.title("Heatmap: Average Delay (Duration) by Airport and Time of Day")
plt.xlabel("Time of Day")
plt.ylabel("Source Airport")
plt.show()

# %%
# Pivot table: average delay for each route
delay_route = df.pivot_table(
    index='source_city',
    columns='destination_city',
    values='duration',
    aggfunc='mean'
)

plt.figure(figsize=(14,7))
sns.heatmap(delay_route, annot=True, fmt=".2f", cmap='Oranges')
plt.title("Delay Heatmap: Average Duration by Route (Source → Destination)")
plt.xlabel("Destination City")
plt.ylabel("Source City")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.countplot(data=df, y='source_city', order=df['source_city'].value_counts().index)
plt.title("Busiest Airports (Most Departures)")
plt.xlabel("Number of Flights")
plt.ylabel("Airport")
plt.show()

# %%
avg_delay_airport = df.groupby('source_city')['duration'].mean().sort_values()

plt.figure(figsize=(10,6))
sns.barplot(x=avg_delay_airport.values, y=avg_delay_airport.index)
plt.title("Average Delay (Duration) by Airport")
plt.xlabel("Average Duration (hours)")
plt.ylabel("Airport")
plt.show()

# %%
df['Route'] = df['source_city'] + " → " + df['destination_city']

# %%
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price           Route
# 0           Mumbai  Economy      2.17          1   5953  Delhi → Mumbai
# 1           Mumbai  Economy      2.33          1   5953  Delhi → Mumbai
# 2           Mumbai  Economy      2.17          1   5956  Delhi → Mumbai
# 3           Mumbai  Economy      2.25          1   5955  Delhi → Mumbai
# 4           Mumbai  Economy      2.33          1   5955  Delhi → Mumbai

# %%
top_routes = df['Route'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=top_routes.values, y=top_routes.index)
plt.title("Top 10 Most Popular Routes")
plt.xlabel("Number of Flights")
plt.ylabel("Route")
plt.show()

# %% [markdown]
# **Week 6: Seasonal and Cancellation Analysis**
#
# • Monthly cancellation trends
#
# • Cancellation types: carrier, weather, security, NAS
#
# • Analyze impact of holidays or winter months

# %%
import pandas as pd

from google.colab import files
uploaded = files.upload()

# Load the uploaded CSV
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)

df.head()
# Out:
#      <input type="file" id="files-520e5d21-c74c-4579-83e5-9a84c596e664" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-520e5d21-c74c-4579-83e5-9a84c596e664">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='days_left', y='duration', alpha=0.4)
plt.title("Seasonal Stress Proxy: Booking Window vs Duration")
plt.xlabel("Days Before Departure")
plt.ylabel("Flight Duration (Delay Proxy)")
plt.show()

# %%
carrier_delay = df.groupby('airline')['duration'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=carrier_delay.values, y=carrier_delay.index)
plt.title("Carrier-related Cancellation Proxy (Avg Duration by Airline)")
plt.xlabel("Average Duration (hours)")
plt.ylabel("Airline")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='departure_time', y='duration')
plt.title("Weather-related Cancellation Proxy (Time of Day vs Duration)")
plt.xlabel("Time of Day")
plt.ylabel("Duration (hours)")
plt.show()

# %%
nas_delay = df.groupby('source_city')['duration'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=nas_delay.values, y=nas_delay.index)
plt.title("NAS-related Cancellation Proxy (Airport Congestion)")
plt.xlabel("Average Duration (hours)")
plt.ylabel("Source Airport")
plt.show()

# %%
summary = pd.DataFrame({
    "Carrier": carrier_delay.head(1).values,
    "Weather": [df.groupby('departure_time')['duration'].mean().max()],
    "NAS": nas_delay.head(1).values
}, index=["Max Avg Duration"])

summary.plot(kind='bar', figsize=(6,4), legend=True)
plt.title("Comparison of Cancellation Proxies")
plt.ylabel("Average Duration")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='days_left', y='duration', alpha=0.4)
plt.title("Holiday Impact Proxy: Booking Window vs Duration")
plt.xlabel("Days Before Departure")
plt.ylabel("Duration (hours)")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df, x='departure_time', y='duration')
plt.title("Winter Impact Proxy: Time of Day vs Duration")
plt.xlabel("Time of Day")
plt.ylabel("Duration (hours)")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.boxplot(data=df, x='stops', y='duration')
plt.title("Seasonal Stress: Stops vs Duration")
plt.xlabel("Number of Stops")
plt.ylabel("Duration (hours)")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, x='airline', y='duration')
plt.xticks(rotation=45)
plt.title("Delay Distribution by Airline")
plt.show()

# %%
import numpy as np

plt.figure(figsize=(6,4))
for airline in df['airline'].unique()[:3]:
    subset = df[df['airline'] == airline]['duration']
    sns.ecdfplot(subset, label=airline)

plt.legend()
plt.title("Probability of Delay by Airline (ECDF)")
plt.xlabel("Duration")
plt.ylabel("Probability")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.stripplot(data=df, x='stops', y='duration', jitter=True)
plt.title("Delay Spread by Number of Stops")
plt.show()

# %%
# !pip install squarify
import squarify

sizes = df['airline'].value_counts()
labels = sizes.index

plt.figure(figsize=(7,5))
squarify.plot(sizes=sizes, label=labels)
plt.title("Flight Share by Airline (Treemap)")
plt.axis('off')
plt.show()

# %%
delay_contrib = df.groupby('airline')['duration'].sum().sort_values()

delay_contrib.plot(kind='area', figsize=(8,5))
plt.title("Cumulative Delay Contribution by Airline")
plt.xlabel("Airline")
plt.ylabel("Total Delay")
plt.show()

# %%
import numpy as np

time_delay = df.groupby('departure_time')['duration'].mean()
angles = np.linspace(0, 2*np.pi, len(time_delay), endpoint=False)

plt.figure(figsize=(6,6))
plt.polar(angles, time_delay.values)
plt.xticks(angles, time_delay.index)
plt.title("Average Delay by Time of Day (Polar Plot)")
plt.show()

# %%
# !pip install joypy

# %%
import joypy
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
joypy.joyplot(
    df,
    by="airline",
    column="duration",
    figsize=(10,6),
    colormap=plt.cm.Reds
)
plt.title("Delay Distribution by Airline (Ridgeline Plot)")
plt.show()

# %% [markdown]
# **Key Insights**
#
# 1.Peak seasons and holidays increase flight delays.
#
# 2.Morning and evening flights are more affected due to winter weather.
#
# 3.Busy airports face higher congestion-related delays.
#
# 4.Some airlines show consistently higher delays.
#
# 5.Multi-stop flights experience more delays than non-stop flights.
